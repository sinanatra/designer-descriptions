# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def get_absolute_favicon_url(base_url, relative_url):
    try:
        if relative_url.startswith(('http://', 'https://')):
            return relative_url

        absolute_url = urljoin(base_url, relative_url)
        return absolute_url
    except Exception as e:
        print(f"Error converting relative URL to absolute: {e}")
        return None

def get_favicon_url(url):
    try:
        retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
        adapter = HTTPAdapter(max_retries=retries)
        session = requests.Session()
        session.mount('http://', adapter)
        session.mount('https://', adapter)

        response = session.get(url, verify=False, timeout=5)
        response.raise_for_status()

        soup = BeautifulSoup(response.text, 'html.parser')
        favicon_tag = soup.find('link', rel='icon') or soup.find('link', rel='shortcut icon')
        favicon_url = favicon_tag['href'] if favicon_tag else None
        return get_absolute_favicon_url(url, favicon_url) if favicon_url else None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching favicon for {url}: {e}")
        return None

df = pd.read_csv('data.csv')
df['favicon_url'] = df['url'].apply(get_favicon_url)
df.to_csv('data2.csv', index=False)
# Out:
# Error fetching favicon for https://futurecorp.london: HTTPSConnectionPool(host='futurecorp.london', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x15ea68c50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://momentfactory.com: HTTPSConnectionPool(host='momentfactory.com', port=443): Max retries exceeded with url: / (Caused by ResponseError('too many 500 error responses'))
# Error fetching favicon for http://www.zhestkov.com: HTTPConnectionPool(host='www.zhestkov.com', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x168b91d90>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for http://urmston.xyz: 436 Client Error:  for url: http://urmston.xyz/
# Error fetching favicon for https://www.minmax.design: HTTPSConnectionPool(host='www.minmax.design', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x168e99990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://foam.studio: 404 Client Error: Not Found for url: https://foam.studio/
# Error fetching favicon for https://carla-karlis.ch: 403 Client Error: Forbidden for url: https://carla-karlis.ch/
# Error fetching favicon for https://special-offer.studio: 404 Client Error: Not Found for url: https://special-offer.studio/
# Error fetching favicon for https://huiteh.net: HTTPSConnectionPool(host='huiteh.net', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x16902a5d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://originaltype.com: 403 Client Error: Forbidden for url: https://originaltype.com/
# Error fetching favicon for https://hawraf.com: HTTPSConnectionPool(host='hawraf.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1698c9d50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://pastorplaczek.com: HTTPSConnectionPool(host='pastorplaczek.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169c91310>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://workingnotworking.com: 403 Client Error: Forbidden for url: https://workingnotworking.com/
# Error fetching favicon for https://rckt.com: 403 Client Error: Forbidden for url: https://rckt.com/
# Error fetching favicon for http://www.fileunderpopular.com: HTTPConnectionPool(host='www.fileunderpopular.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x169e5a450>, 'Connection to www.fileunderpopular.com timed out. (connect timeout=5)'))
# Error fetching favicon for https://armarchitecture.com.au: 403 Client Error: Forbidden for url: https://armarchitecture.com.au/
# Error fetching favicon for http://www.createwithmalte.de: HTTPConnectionPool(host='www.createwithmalte.de', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x168c91210>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://2x4.org: 403 Client Error: Forbidden for url: https://2x4.org/
# Error fetching favicon for https://http.studio: HTTPSConnectionPool(host='http.studio', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x169814610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://bb.agency: 403 Client Error: Forbidden for url: https://bb.agency/
# Error fetching favicon for http://www.martijndeheer.nl: HTTPConnectionPool(host='www.martijndeheer.nl', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x169817610>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for http://aptoptout.studio: HTTPConnectionPool(host='aptoptout.studio', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x169c93ed0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
# Error fetching favicon for https://www.tim-peters.net: 406 Client Error: Not Acceptable for url: https://www.tim-peters.net/
# Error fetching favicon for https://nibressergo.com: HTTPSConnectionPool(host='nibressergo.com', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x169201cd0>, 'Connection to nibressergo.com timed out. (connect timeout=5)'))
# Error fetching favicon for https://liftoffdesignstudio.com: 406 Client Error: Not Acceptable for url: https://liftoffdesignstudio.com/
# Error fetching favicon for https://wimwepster.nl: 403 Client Error: Forbidden for url: https://wimwepster.nl/
# Error fetching favicon for https://littlefragments.com: 403 Client Error: Forbidden for url: https://littlefragments.com/

# %% [markdown]
# ###  Save Images

# %%
import os
df = pd.read_csv('data2.csv')

img_folder = 'img'
os.makedirs(img_folder, exist_ok=True)

def download_and_save_favicon(url, save_folder):
    try:
        # Configure retry strategy for network issues
        retries = Retry(total=5, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
        adapter = HTTPAdapter(max_retries=retries)
        session = requests.Session()
        session.mount('http://', adapter)
        session.mount('https://', adapter)

        # Fetch the favicon URL with retries and SSL verification disabled
        response = session.get(url, verify=False, timeout=5)
        response.raise_for_status()

        # Extract filename from URL
        filename = url.split("/")[-1]

        # Save the favicon image to the specified folder
        with open(os.path.join(save_folder, filename), 'wb') as f:
            f.write(response.content)

        print(f"Successfully downloaded and saved favicon for {url}")
    except requests.exceptions.RequestException as e:
        print(f"Error downloading favicon for {url}: {e}")

for index, row in df.iterrows():
    favicon_url = row['favicon_url']
    if favicon_url:
        download_and_save_favicon(favicon_url, img_folder)
# Out:
# Successfully downloaded and saved favicon for https://rectangle.design/wp-content/themes/rectangle/favicon-32x32.png
# Successfully downloaded and saved favicon for https://rulesrulesrules.studio/favicon.ico
# Successfully downloaded and saved favicon for https://bus.group/assets/favicon-4TLS4Q2E.png
# Successfully downloaded and saved favicon for https://www.datocms-assets.com/8504/1549364939-rndrlogo.jpg?auto=format&h=16&w=16
# Successfully downloaded and saved favicon for https://veravandeseyp.com/site/templates//images/favicon.ico
# Successfully downloaded and saved favicon for http://www.fredericbrodbeck.de/favicon.ico
# Successfully downloaded and saved favicon for https://cdn.sanity.io/images/lrtvpz57/production/3d716c36bddc0d5a2fdf43379dec8315dd4109a5-320x320.svg?w=512&h=512&fm=png
# Successfully downloaded and saved favicon for https://www.onformative.com/favicon.ico
# Successfully downloaded and saved favicon for https://studiomoniker.com/assets/images/favico.png
# Successfully downloaded and saved favicon for https://waltzbinaire.com/wp-content/uploads/2020/01/Favicon.png
# Successfully downloaded and saved favicon for https://klimaiteklimaite.com/favicon-32x32.png
# Error downloading favicon for data:image/x-icon;base64,...: No connection adapters were found for 'data:image/x-icon;base64,...'
# Successfully downloaded and saved favicon for https://rlon.com/wp-content/uploads/2016/11/cropped-rlon_favicon-150x150.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for http://stephdavidson.com/favicon-32x32.png?v=b2e48ef35fb872490d3cf80f1adb6415
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://d3f1fx6enveicv.cloudfront.net/assets/favicon-d5ce50e1cbe4f9b9b868296f4905b2446f179f59b2efbd806620b5192fa5266d.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for http://catk.de/favicon-32x32.png
# Successfully downloaded and saved favicon for http://www.ok-rm.co.uk/wp-content/uploads/2014/02/c9dc545b3b1e0c370177e2aaa4358545.png
# Successfully downloaded and saved favicon for https://sehsucht.de/typo3conf/ext/pxsehsucht/Resources/Public/Favicons/favicon-16x16.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://www.therodina.com/favicon-32x32.png
# Successfully downloaded and saved favicon for https://koosbreen.com/site/templates/favicon.ico
# Successfully downloaded and saved favicon for https://no-plans.com/np-favicon.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://images.squarespace-cdn.com/content/v1/53c9cdf3e4b0669c8d19e691/1406448512728-IV8KQ0OEY2IRBPFRGVKX/favicon.ico
# Successfully downloaded and saved favicon for http://www.teyosh.com/favicon.ico
# Successfully downloaded and saved favicon for https://sansho.studio/assets/img/favicon.ico
# Successfully downloaded and saved favicon for https://freight.cargo.site/t/original/i/8cef20549db91c3d245844625767a6719421aa854e598f21aafad0968fe2f3fb/fav_ws_sphere.ico
# Successfully downloaded and saved favicon for https://assets-global.website-files.com/635682bea1b0688ca665b979/6538d415a7b4adae67354fbe_kids.jpg
# Successfully downloaded and saved favicon for http://studioscholz.info/favicon.ico
# Successfully downloaded and saved favicon for http://thedesignoffice.org/wp-content/themes/dev/lib/img/favicons/favicon.ico
# Successfully downloaded and saved favicon for https://vmragona.com/wp-content/uploads/2022/12/ef36f76d71a733cb134417c27b237ec3_coin_gigapixel_very_compressed-3.png
# Successfully downloaded and saved favicon for http://samtripp.com/favicon-32x32.png
# Successfully downloaded and saved favicon for https://commonworks.co.uk/images/favicon.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://64.media.tumblr.com/avatar_821c5ef05514_128.pnj
# Successfully downloaded and saved favicon for http://www.playlab.org/static/images/j-fav.png
# Successfully downloaded and saved favicon for https://n-e-r-v-o-u-s.com/shop/images/nervous_n_transparent.png
# Successfully downloaded and saved favicon for https://assets-global.website-files.com/62987a822e60efe0f9ea7bb2/62ac7fe78daf5f397c6949f2_Unmade-favicon.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://dow-smith.com/assets/img/favicon.png
# Successfully downloaded and saved favicon for http://www.thibault.io/favicon.jpg
# Successfully downloaded and saved favicon for https://www.zeitguised.com/wp-content/uploads/2023/09/cropped-zeitguised_fav_icon-32x32.jpg
# Successfully downloaded and saved favicon for https://newnow.cool/images/favicon.png
# Successfully downloaded and saved favicon for https://noservice.today/wp-content/uploads/2021/07/cropped-NOS_favicon-32x32.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for http://franrios.com/wp-content/uploads/2018/10/cropped-franriosfavicon-32x32.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for http://mihaicernusca.com/favicon-32x32.png
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://benedikt-gross.de/favicons/favicon_original.svg
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://proxi.me/wp-content/themes/proxi/favicon.ico
# Error downloading favicon for data:image/svg+xml,<svg xmlns=%22http://www.w3.org/2000/svg%22 viewBox=%220 0 100 100%22><text y=%22.9em%22 font-size=%2290%22>ð¦ </text></svg>: No connection adapters were found for 'data:image/svg+xml,<svg xmlns=%22http://www.w3.org/2000/svg%22 viewBox=%220 0 100 100%22><text y=%22.9em%22 font-size=%2290%22>ð\x9f¦\xa0</text></svg>'
# Successfully downloaded and saved favicon for https://paralleluniver.se/wp-content/uploads/2021/07/P-removebg-preview-150x150.png
# Error downloading favicon for https://www.gillesdebrock.nl/Favicon_Image_Location: 404 Client Error: Not Found for url: https://www.gillesdebrock.nl/Favicon_Image_Location
# Error downloading favicon for nan: Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan?
# Successfully downloaded and saved favicon for https://dvtk.us/assets/images/favicon/letters/1.png
# Successfully downloaded and saved favicon for https://ufomammoot.de/favicon.ico
# Successfully downloaded and saved favicon for https://framerusercontent.com/images/xEHPJoG3u6kPjRkSxKRIb7ji0.png
# Successfully downloaded and saved favicon for https://artcom.de/wp-content/themes/artcom2014/images/favicon.ico
# Successfully downloaded and saved favicon for http://kohlberger.net/Favicon.ico
# Successfully downloaded and saved favicon for https://bennelsen.com/site/themes/bennelsen/img/favicons/favicon-32x32.png
# Successfully downloaded and saved favicon for https://64.media.tumblr.com/avatar_18a87a4e614b_128.pnj
# Successfully downloaded and saved favicon for https://www.abcdinamo.com/assets/favicon/favicon.svg
# Successfully downloaded and saved favicon for https://frnsys.com/assets/favicon.ico
# Successfully downloaded and saved favicon for https://www.geckelermichels.com/wp-content/themes/geckelermichels/assets/images/favicon-16x16.png
# Successfully downloaded and saved favicon for http://stewartsmith.io/favicon-192.png
